# %% [markdown]
# <a href="https://colab.research.google.com/github/suelen-prs/EBAC/blob/main/Modulo17_exercicio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Árvores II - Tarefa 2

# %% [markdown]
# ### 1. Carregar as bases
#
# Vamos carregar as bases lidas na tarefa passada. Se você salvou essas bases em arquivo texto, basta fazer a leitura com o comando ```pd.read_csv``` das seguintes bases:
#
# - X_train
# - Y_train
# - X_test
# - Y_test
#
# Não se esqueça de considerar a leitura dos índices dos arquivos no ```read_csv()```!

# %%
# !pip install -U scikit-learn

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay

# %%
_features = 'features.txt'
_subject_train = 'subject_train.txt'
_X_train = 'X_train.txt'
_subject_test = 'subject_test.txt'
_X_test = 'X_test.txt'
_y_train = 'y_train.txt'
_y_test = 'y_test.txt'

# %%
features = (pd.read_csv(filepath_or_buffer=_features, sep='?', header=None).squeeze('columns'))
features
# Out:
# 0                           1 tBodyAcc-mean()-X
# 1                           2 tBodyAcc-mean()-Y
# 2                           3 tBodyAcc-mean()-Z
# 3                            4 tBodyAcc-std()-X
# 4                            5 tBodyAcc-std()-Y
#                          ...
# 556        557 angle(tBodyGyroMean,gravityMean)
# 557    558 angle(tBodyGyroJerkMean,gravityMean)
# 558                    559 angle(X,gravityMean)
# 559                    560 angle(Y,gravityMean)
# 560                    561 angle(Z,gravityMean)
# Name: 0, Length: 561, dtype: object

# %%
subject_train = (pd.read_csv(filepath_or_buffer=_subject_train, header=None).squeeze('columns'))
subject_train
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 7347    30
# 7348    30
# 7349    30
# 7350    30
# 7351    30
# Name: 0, Length: 7352, dtype: int64

# %%
X_train = (pd.read_csv(filepath_or_buffer=_X_train, header=None, names=features, delim_whitespace=True).assign(subject_train=subject_train))
X_train.set_index(keys='subject_train', drop=True, append=True, inplace=True)
X_train
# Out:
#                     1 tBodyAcc-mean()-X  2 tBodyAcc-mean()-Y  \
#      subject_train
# 0    1                         0.288585            -0.020294
# 1    1                         0.278419            -0.016411
# 2    1                         0.279653            -0.019467
# 3    1                         0.279174            -0.026201
# 4    1                         0.276629            -0.016570
# ...                                 ...                  ...
# 7347 30                        0.299665            -0.057193
# 7348 30                        0.273853            -0.007749
# 7349 30                        0.273387            -0.017011
# 7350 30                        0.289654            -0.018843
# 7351 30                        0.351503            -0.012423
#
#                     3 tBodyAcc-mean()-Z  4 tBodyAcc-std()-X  \
#      subject_train
# 0    1                        -0.132905           -0.995279
# 1    1                        -0.123520           -0.998245
# ...

# %%
print('Quantidade de valores ausentes em X_train:', X_train.isna().sum().sum())
# Out:
# Quantidade de valores ausentes em X_train: 0

# %%
subject_test = (pd.read_csv(filepath_or_buffer=_subject_test, header=None).squeeze('columns'))

X_test = (pd.read_csv(filepath_or_buffer=_X_test, header=None, names=features, delim_whitespace=True).assign(subject_test=subject_test))
X_test.set_index(keys='subject_test', drop=True, append=True, inplace=True)
X_test
# Out:
#                    1 tBodyAcc-mean()-X  2 tBodyAcc-mean()-Y  \
#      subject_test
# 0    2                        0.257178            -0.023285
# 1    2                        0.286027            -0.013163
# 2    2                        0.275485            -0.026050
# 3    2                        0.270298            -0.032614
# 4    2                        0.274833            -0.027848
# ...                                ...                  ...
# 2942 24                       0.310155            -0.053391
# 2943 24                       0.363385            -0.039214
# 2944 24                       0.349966             0.030077
# 2945 24                       0.237594             0.018467
# 2946 24                       0.153627            -0.018437
#
#                    3 tBodyAcc-mean()-Z  4 tBodyAcc-std()-X  \
#      subject_test
# 0    2                       -0.014654           -0.938404
# 1    2                       -0.119083           -0.975415
# ...

# %%
print('Quantidade de valores ausentes em X_test:', X_test.isna().sum().sum())
# Out:
# Quantidade de valores ausentes em X_test: 0

# %%
import os

# %%
os.makedirs(name='./output', exist_ok=True)
X_train.to_csv(path_or_buf='./output/X_train.csv')
X_test.to_csv(path_or_buf='./output/X_test.csv')

# %%
X_train = pd.read_csv('./output/X_train.csv', index_col=['Unnamed: 0', 'subject_train'])
X_test = pd.read_csv('./output/X_test.csv', index_col=['Unnamed: 0', 'subject_test'])

# %%
X_train = X_train.iloc[:,:3]
X_test = X_test.iloc[:,:3]

y_train = (pd.read_csv(filepath_or_buffer=_y_train, header=None).squeeze('columns'))
y_test = (pd.read_csv(filepath_or_buffer=_y_test, header=None).squeeze('columns'))

print('X_train:', X_train.shape)
print('y_train:', y_train.shape)
print('X_test:', X_test.shape)
print('y_test:', y_test.shape)
# Out:
# X_train: (7352, 3)
# y_train: (7352,)
# X_test: (2947, 3)
# y_test: (2947,)

# %% [markdown]
# ### 2. Divisão da base em Treino, Validação e Teste
#
# A base já se encontra dividida em Treino e Validação. O que vamos fazer então é extrair uma base de Validação da base de Treino.
#
# Extraia 25% da base de treino como base de validação.

# %%
x_treino, x_validacao, y_treino, y_validacao = train_test_split(X_train, y_train, test_size=0.25)

# %% [markdown]
# ### 3. Melhores 3 variáveis
#
# Rode uma árvore com profundidade máxima igual a 4 para prever a atividade humana com todas as variáveis.
# Observe a importância das variáveis e considere as 3 variáveis com maior importância para os próximos passos.
# Dica: utilize o atributo ```clf.feature_importances_``` da árvore treinada.

# %%
clf = DecisionTreeClassifier(max_depth=4).fit(x_treino, y_treino)

importances = clf.feature_importances_

importances
# Out:
# array([0.67479704, 0.24079905, 0.0844039 ])

# %%
# Dataframe para identificar variável corresponde a cada valor
importancias_variaveis = pd.DataFrame({
    'nome_coluna': x_treino.columns,
    'importance': importances
})

# Nome das 3 colunas mais significativas para o modelo
colunas_significativas = importancias_variaveis.sort_values(by = 'importance').tail(3)['nome_coluna']

colunas_significativas
# Out:
# 2    3 tBodyAcc-mean()-Z
# 1    2 tBodyAcc-mean()-Y
# 0    1 tBodyAcc-mean()-X
# Name: nome_coluna, dtype: object

# %% [markdown]
# ### 4. Construa uma árvore com as 3 melhores variáveis
#
# Utilizando as três variáveis encontradas acima, construa uma árvore de decisão. Encontre o melhor ```ccp_alpha``` utilizando a base de validação, conforme a estrutura que vimos em aula.

# %%
# %%time
# Reduzo a 3 colunas selecionadas no passo anterior
x_treino    = x_treino[colunas_significativas]
x_validacao = x_validacao[colunas_significativas]
x_teste     = X_test[colunas_significativas]

# Modelo criação
modelo = DecisionTreeClassifier()

# Lista de ccps_alpha
ccps = modelo.cost_complexity_pruning_path(x_treino, y_treino).ccp_alphas
# Out:
# CPU times: user 64.3 ms, sys: 0 ns, total: 64.3 ms
# Wall time: 66.6 ms

# %%
# %%time

lista_modelo = []
lista_scores = []


for ccp in ccps:

    # Treinar modelo
    modelo = DecisionTreeClassifier(ccp_alpha=ccp).fit(x_treino, y_treino)
    lista_modelo.append(modelo)

    # Cálcular a acurácia
    lista_scores.append( modelo.score(x_validacao, y_validacao) )


# Dataframe para avaliar os resultados
df_resultados = pd.DataFrame({

    'modelo': lista_modelo,
    'ccp': ccps,
    'score': lista_scores

})

df_resultados
# Out:
# CPU times: user 1min 7s, sys: 166 ms, total: 1min 7s
# Wall time: 1min 7s
#                                                  modelo       ccp     score
# 0                              DecisionTreeClassifier()  0.000000  0.413493
# 1     DecisionTreeClassifier(ccp_alpha=0.00012090436...  0.000121  0.404788
# 2     DecisionTreeClassifier(ccp_alpha=0.00012090436...  0.000121  0.411317
# 3     DecisionTreeClassifier(ccp_alpha=0.00012090436...  0.000121  0.399891
# 4     DecisionTreeClassifier(ccp_alpha=0.00012090436...  0.000121  0.399347
# ...                                                 ...       ...       ...
# 1256  DecisionTreeClassifier(ccp_alpha=0.00588460668...  0.005885  0.375952
# 1257  DecisionTreeClassifier(ccp_alpha=0.00599217907...  0.005992  0.364527
# 1258  DecisionTreeClassifier(ccp_alpha=0.00720635513...  0.007206  0.336235
# 1259  DecisionTreeClassifier(ccp_alpha=0.01023820664...  0.010238  0.288901
# ...

# %%
df_resultados.sort_values(by = 'score', ascending=False)
# Out:
#                                                  modelo       ccp     score
# 1218  DecisionTreeClassifier(ccp_alpha=0.00094718277...  0.000947  0.453210
# 1219  DecisionTreeClassifier(ccp_alpha=0.00101909235...  0.001019  0.453210
# 1206  DecisionTreeClassifier(ccp_alpha=0.00079821543...  0.000798  0.453210
# 1217  DecisionTreeClassifier(ccp_alpha=0.00091029544...  0.000910  0.452666
# 1205  DecisionTreeClassifier(ccp_alpha=0.00079514744...  0.000795  0.452666
# ...                                                 ...       ...       ...
# 1255  DecisionTreeClassifier(ccp_alpha=0.00547238072...  0.005472  0.369967
# 1257  DecisionTreeClassifier(ccp_alpha=0.00599217907...  0.005992  0.364527
# 1258  DecisionTreeClassifier(ccp_alpha=0.00720635513...  0.007206  0.336235
# 1259  DecisionTreeClassifier(ccp_alpha=0.01023820664...  0.010238  0.288901
# 1260  DecisionTreeClassifier(ccp_alpha=0.03518852129...  0.035189  0.288901
#
# [1261 rows x 3 columns]

# %% [markdown]
# ### 5. Avaliação do modelo
#
# Avalie a árvore encontrada no item anterior na base de testes.

# %%
melhor_modelo = df_resultados.loc[ df_resultados['score'].idxmax(), 'modelo']

# %%
print(f'Acurácia treino    = {melhor_modelo.score(x_treino, y_treino)}')
print(f'Acurácia validação = {melhor_modelo.score(x_validacao, y_validacao)}')
print(f'Acurácia teste     = {melhor_modelo.score(x_teste, y_test)}')
# Out:
# Acurácia treino    = 0.519949220166848
# Acurácia validação = 0.45321001088139284
# Acurácia teste     = 0.4397692568713946
